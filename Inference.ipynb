# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
import cv2
import numpy as np
from glob import glob
from models import Yolov4

# %%
model = Yolov4(weight_path='E:\Darsh\DP\Internship and Works\AtliQ Technologies\Object Detection Model\yolo-v4-tf.keras-master\yolov4.weights', 
               class_name_path='E:\Darsh\DP\Internship and Works\AtliQ Technologies\Object Detection Model\yolo-v4-tf.keras-master\class_names\coco_classes.txt')
# Out:
# nms iou: 0.413 score: 0.3
# all weights read
# load from E:\Darsh\DP\Internship and Works\AtliQ Technologies\Object Detection Model\yolo-v4-tf.keras-master\yolov4.weights
# C:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model.predict('E:\Darsh\DP\Internship and Works\AtliQ Technologies\Object Detection Model\yolo-v4-tf.keras-master\input.jpg', random_color=True)
# Out:
# img shape:  (474, 474, 3)
# # of bboxes: 1
#     x1  y1   x2   y2 class_name     score    w    h
# 0  115  20  356  449        cup  0.476143  241  429

# %%
import numpy as np
import argparse
import time
import cv2
import os
import pandas as pd
import fiftyone as fo
import fiftyone.zoo as foz
dataset = foz.load_zoo_dataset(
              "open-images-v6",
              split="validation",
              label_types=["detections"],
              classes=["Bottle", "Tin can"],
              max_samples=100,
          )
# Out:
# ...
#  100% |██████████████████| 100/100 [49.5s elapsed, 0s remaining, 3.7 images/s]
# Dataset info written to 'C:\Users\DELL\fiftyone\open-images-v6\info.json'
# Loading 'open-images-v6' split 'validation'
#  100% |█████████████████| 100/100 [1.0s elapsed, 0s remaining, 98.0 samples/s]
# Dataset 'open-images-v6-validation-100' created
